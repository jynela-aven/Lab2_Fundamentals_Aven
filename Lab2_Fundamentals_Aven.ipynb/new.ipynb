# %%
target_name = "AVEN"
SEED_NUM = "2"
redacted_name = "A2V2N"

for char in target_name: 


 if char in "AEIOU":
        redacted_name += SEED_NUM 


 else:
    redacted_name += char

print("Redacted_name: , redacted_name")
# Out:
# Redacted_name: , redacted_name

# %%
loops = 25

# %%
verification_hash = (65 * 7) + 25
print(f"Verification Hash: {verification_hash}")
# Out:
# Verification Hash: 480

# %%
ENGINEER_NAME = "AVEN"
first_letter = ENGINEER_NAME[0]
ASCII_VALUE = ord(first_letter)
SEED_NUM = 2
verification_hash = (65 * 7) + 25
print("Verification Hash:", verification_hash)
# Out:
# Verification Hash: 480
